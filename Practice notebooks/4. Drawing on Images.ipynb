# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def imshow(title = 'Image', image = None, size = 5):
    h, w = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
    plt.title(title)
    plt.show()

# %%
# Create a black image using numpy to create and array of black 
image = np.zeros((512,512,3), np.uint8)

# Can we make this in black and white? grayscale
image_gray = np.zeros((512,512), np.uint8)

# Black would be the same as a greyscale or color image (same for white)
imshow("Black Canvas - RGB Color", image)
imshow("Black Canvas - Grayscale", image_gray)

# %%
cv2.line(image, (0,0), (511,511),(255,127,10),5)
imshow('Blue line inside of black background', image)

# %%
cv2.rectangle(image, (50, 50),(419,419),(511,431,56), 5)
imshow('Rectangle', image)

# %%
cv2.circle(image, (350, 350), 100, (211,231,346), -1)
imshow('Circle:', image)

# %%
image = np.zeros((1000, 1000, 3), np.uint8)
ourString = 'Human 100%'
cv2.putText(image, ourString, (160, 400), cv2.FONT_HERSHEY_SIMPLEX, 2, (40, 200, 0), 4)
imshow('Object Detection', image )

# %%
image = np.zeros((1000, 1000, 3), np.uint8)
ourString = 'Human 100%'
cv2.putText(image, ourString, (160, 400), cv2.FONT_HERSHEY_COMPLEX, 2, (40, 200, 0), 4)
imshow('Object Detection', image )

# %%
image = np.zeros((1000, 1000, 3), np.uint8)
ourString = 'Human 100%'
cv2.putText(image, ourString, (160, 400), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 2, (40, 200, 0), 4)
imshow('Object Detection', image )
